# %% [markdown]
# # Request.post()-Methode - Erweiterete Anfrage

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# Curl-Befehl

# %% [markdown]
# curl 'https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search?lang=en&app=2.1.1p1-build-0' -H 'User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:65.0) Gecko/20100101 Firefox/65.0' -H 'Accept: application/json, text/plain, */*' -H 'Accept-Language: en-US,en;q=0.5' --compressed -H 'Referer: https://ec.europa.eu/eures/eures-searchengine/page/main' -H 'ajax-call: true' -H 'Content-Type: application/json;charset=utf-8' -H 'Connection: keep-alive' -H 'Cookie: cck_read=%22en%22; _pk_id.81.1e93=8242111674440e7c.1549812996.7.1549988131.1549985485.; _pk_ref.81.1e93=%5B%22%22%2C%22%22%2C1549988131%2C%22http%3A%2F%2Flocalhost%3A8888%2Fnotebooks%2FData_Projects%2FEURES%2F1.1%20Request.post()-Methode.ipynb%22%5D; EURES_JVSE_SESSIONID=C0HiVWi0tkB7waD2j00m87FF5rLf4bfFfVmzfLg9-wR2yCF8XjUC!-1540004032; _pk_ses.81.1e93=*; eu_cookie_consent=%7B%22a%22%3A%7B%22document.domain%22%3A%5B%22_gat%22%2C%22_ga%22%2C%22jobVacancy%22%2C%22ISCOLang%22%5D%7D%2C%22r%22%3A%7B%7D%7D; _ga=GA1.2.1678820704.1549813001; _gid=GA1.2.780842180.1549813001' --data '{"keywords":[],"positionScheduleCodes":[],"positionOfferingCodes":[],"educationLevelCodes":[],"euresFlagCodes":[],"nutsCodes":["ch"],"notSpecifiedInNutsCodes":[],"requiredExperienceCodes":[],"solidarityContextCodes":[],"otherBenefitsCodes":[],"occupationUris":[],"includeJobsWithoutBenefits":false,"requiredLanguages":[],"includeJobsWithoutRequiredLanguages":false,"sortSearch":"BEST_MATCH","resultsPerPage":10,"page":1,"sessionId":"ljgk7x0nrc8sckwzb1zqn"}'

# %% [markdown]
# Curl-Befehl in Python-Anfrage umwandeln mit https://curl.trillworks.com/

# %% [markdown]
# 1.Test statt "resultsPerPage":10 neu "resultsPerPage":100 eingeben

# %%
cookies = {
    'cck_read': '%22en%22',
    '_pk_id.81.1e93': '8242111674440e7c.1549812996.7.1549988131.1549985485.',
    '_pk_ref.81.1e93': '%5B%22%22%2C%22%22%2C1549988131%2C%22http%3A%2F%2Flocalhost%3A8888%2Fnotebooks%2FData_Projects%2FEURES%2F1.1%20Request.post()-Methode.ipynb%22%5D',
    'EURES_JVSE_SESSIONID': 'C0HiVWi0tkB7waD2j00m87FF5rLf4bfFfVmzfLg9-wR2yCF8XjUC!-1540004032',
    '_pk_ses.81.1e93': '*',
    'eu_cookie_consent': '%7B%22a%22%3A%7B%22document.domain%22%3A%5B%22_gat%22%2C%22_ga%22%2C%22jobVacancy%22%2C%22ISCOLang%22%5D%7D%2C%22r%22%3A%7B%7D%7D',
    '_ga': 'GA1.2.1678820704.1549813001',
    '_gid': 'GA1.2.780842180.1549813001',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:65.0) Gecko/20100101 Firefox/65.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://ec.europa.eu/eures/eures-searchengine/page/main',
    'ajax-call': 'true',
    'Content-Type': 'application/json;charset=utf-8',
    'Connection': 'keep-alive',
}

params = (
    ('lang', 'en'),
    ('app', '2.1.1p1-build-0'),
)

data = '{"keywords":[],"positionScheduleCodes":[],"positionOfferingCodes":[],"educationLevelCodes":[],"euresFlagCodes":[],"nutsCodes":["ch"],"notSpecifiedInNutsCodes":[],"requiredExperienceCodes":[],"solidarityContextCodes":[],"otherBenefitsCodes":[],"occupationUris":[],"includeJobsWithoutBenefits":false,"requiredLanguages":[],"includeJobsWithoutRequiredLanguages":false,"sortSearch":"BEST_MATCH","resultsPerPage":50,"page":1,"sessionId":"ljgk7x0nrc8sckwzb1zqn"}'

response = requests.post('https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search', headers=headers, params=params, cookies=cookies, data=data)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.post('https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search?lang=en&app=2.1.1p1-build-0', headers=headers, cookies=cookies, data=data)

# %%
print(response.text)
# Out:
# {"numberRecords":4694,"jvs":[{"id":"MDgzR1dTWiA5","creationDate":1549369907000,"lastModificationDate":1549985481000,"title":"Serveur / Serveuse de bar-brasserie","description":"Pour ce Lounge Bar, restaurant et terrasse, vous effectuerez le service au comptoir, en salle, en terrasse, de boissons chaudes ou froides selon la législation relative à la consommation des alcools. Vous entretiendrez la verrerie, les équipements du bar et les locaux selon les règles d'hygiène.<br>Vous avez un an minimum d'expérience dans le domaine.<br>Date d'entrée en service : dès que possible<br>Contrat de saison (CDD ou CDI)<br>Salaire mensuel NET 2 200 € + pourboires<br>Logement et nourriture mis à disposition par l'employeur.<br>Travail hebdomadaire 45 heures/semaine<br>Nombre jours de travail /semaine : 5 jours<br>Envoyer un CV actualisé.","numberOfPosts":1,"locationMap":{"CH":[null]},"euresFlag":false,"jobCategoriesCodes":["http://data.europa.eu/esco/isco/C5131"],"employer":{"name":"GRAND HOTEL DU GO
# ...

# %%
response.json()
# Out:
# {'numberRecords': 4694,
#  'jvs': [{'id': 'MDgzR1dTWiA5',
#    'creationDate': 1549369907000,
#    'lastModificationDate': 1549985481000,
#    'title': 'Serveur / Serveuse de bar-brasserie',
#    'description': "Pour ce Lounge Bar, restaurant et terrasse, vous effectuerez le service au comptoir, en salle, en terrasse, de boissons chaudes ou froides selon la législation relative à la consommation des alcools. Vous entretiendrez la verrerie, les équipements du bar et les locaux selon les règles d'hygiène.<br>Vous avez un an minimum d'expérience dans le domaine.<br>Date d'entrée en service : dès que possible<br>Contrat de saison (CDD ou CDI)<br>Salaire mensuel NET 2 200 € + pourboires<br>Logement et nourriture mis à disposition par l'employeur.<br>Travail hebdomadaire 45 heures/semaine<br>Nombre jours de travail /semaine : 5 jours<br>Envoyer un CV actualisé.",
#    'numberOfPosts': 1,
#    'locationMap': {'CH': [None]},
#    'euresFlag': False,
# ...

# %% [markdown]
# funktionert! Der Code muss einfach abgeändert werden wie folgt: "resultsPerPage":10 auf "resultsPerPage": 4678 . Das entspricht der Anzahl Suchresultate.

# %%
# Wie muss ich den Code so abändern, dass es mir alle relevanten Informationen eines Job-Inserates in eine Tabelle packt?
# Ein Inserat umfasst folgende Angaben:

    {'id': 'MDgxU1ZLWCA5',
   'creationDate': 1546412515000,
   'lastModificationDate': 1549976547000,
   'title': 'Charpentier / Charpentière',
   'description': 'Travaux de Rénovation et neuf<br>Lecture de plans<br>Prise de côtes<br>Pose de bardage et de lambris intérieur/extérieur<br>Taille de charpente<br>Réalisation et finitions extérieures<br>Couverture : Pose de tuiles, lattage, contre lattage, isolation, faîtage',
   'numberOfPosts': 1,
   'locationMap': {'CH': [None]},
   'euresFlag': False,
   'jobCategoriesCodes': ['http://data.europa.eu/esco/isco/C7115'],
   'employer': {'name': 'NOVATIS', 'website': None, 'sectorCodes': []},
   'score': None}
# Out:
#   File "<ipython-input-13-2afd89b24e8f>", line 4
#     {'id': 'MDgxU1ZLWCA5',
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Ich brauche folgende Spalten!
#
# id
# creationDate
# lastModificationDate
# title
# description
# numberOfPosts
# locationMap
# euresFlag
# jobCategoriesCodes
# employer (nur Name)
# score

# %% [markdown]
# Schritt 1: Outout als json file abspeichern
#
# Schritt 2: Json in CSV Konvertieren: https://json-csv.com/
