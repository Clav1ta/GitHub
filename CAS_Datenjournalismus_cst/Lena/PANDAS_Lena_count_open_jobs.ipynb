# %% [markdown]
# ## Libraries importieren

# %%
import pandas as pd

# %% [markdown]
# ## Daten einlesen
#
# Die Daten sind als csv-Daten im gleichen Ordner abgelegt, versehen mit dem Datum wann die Seite gescrapt wurde.

# %%
path = "anzahl_jobs_04-11-2018.csv"

with open(path) as f:
    dateiinhalt = f.read()

# %%
print(dateiinhalt)

# @ THIERRY: Hier fängt mein Problem an. ich will eine tabelle. eine Variable sind Berufsbezeichnungen, das andere das Resultat
# So wie das daher kommt komme ich unten nich weiter! zB alle Resultate zusammenzählen.
# Out:
# Abdichter/in EFZ,Abdichtungspraktiker/in EBA,Agrarpraktiker/in EBA,Anlagen- und Apparatebauer/in EFZ,Anlagenführer/in EFZ,Architekturmodellbauer/in EFZ,Assistent/in Gesundheit und Soziales EBA,Augenoptiker/in EFZ,Automatiker/in EFZ,Automatikmonteur/in EFZ,Automobil-Assistent/in EBA,Automobil-Fachmann/-frau EFZ,Automobil-Mechatroniker/in EFZ,Bäcker/in-Konditor/in-Confiseur/in EBA,Bäcker/in-Konditor/in-Confiseur/in EFZ,Baumaschinenmechaniker/in EFZ,Baupraktiker/in EBA,Bauwerktrenner/in EFZ,Bekleidungsgestalter/in EFZ,Bekleidungsnäher/in EBA,Betonwerker/in EFZ,Boden-Parkettleger/in EFZ,Bootbauer/in EFZ,Bootfachwart/in EFZ,Buchhändler/in EFZ,Büchsenmacher/in EFZ,Bühnentänzer/in EFZ,Büroassistent/in EBA,Carrosserielackierer/in EFZ,Carrosseriespengler/in EFZ,Chemie- und Pharmapraktiker/in EBA,Chemie- und Pharmatechnologe/-login EFZ,Coiffeur/-euse EBA,Coiffeur/-euse EFZ,Dachdecker/in EFZ,Dachdeckerpraktiker/in EBA,Dekorationsnäher/in EBA,Dentalassistent/in EFZ,Detailhandelsassistent/in EBA,
# ...

# %%
# csv-Datei hat keine Kopfzeile. Diese Info muss beim Öffnen mitgegeben werden

df = pd.read_csv(path, header=None)

# %%
df
# Out:
#                 0                            1                      2    \
# 0  Abdichter/in EFZ  Abdichtungspraktiker/in EBA  Agrarpraktiker/in EBA
# 1               135                           44                     57
#
#                                  3                     4    \
# 0  Anlagen- und Apparatebauer/in EFZ  Anlagenführer/in EFZ
# 1                                209                   137
#
#                              5                                         6    \
# 0  Architekturmodellbauer/in EFZ  Assistent/in Gesundheit und Soziales EBA
# 1                              0                                       478
#
#                    7                   8                        9    \
# 0  Augenoptiker/in EFZ  Automatiker/in EFZ  Automatikmonteur/in EFZ
# 1                  122                 365                      103
#
#             ...                                    231  \
# 0           ...             Unterhaltspraktiker/in EBA
# ...

# %%
pd.melt(df)
# Out:
#      variable                                      value
# 0           0                           Abdichter/in EFZ
# 1           0                                        135
# 2           1                Abdichtungspraktiker/in EBA
# 3           1                                         44
# 4           2                      Agrarpraktiker/in EBA
# 5           2                                         57
# 6           3          Anlagen- und Apparatebauer/in EFZ
# 7           3                                        209
# 8           4                       Anlagenführer/in EFZ
# 9           4                                        137
# 10          5              Architekturmodellbauer/in EFZ
# 11          5                                          0
# 12          6   Assistent/in Gesundheit und Soziales EBA
# 13          6                                        478
# 14          7                        Augenoptiker/in EFZ
# ...

# %%
df.dtypes
# Out:
# 0      object
# 1      object
# 2      object
# 3      object
# 4      object
# 5      object
# 6      object
# 7      object
# 8      object
# 9      object
# 10     object
# 11     object
# 12     object
# 13     object
# 14     object
# 15     object
# 16     object
# 17     object
# 18     object
# 19     object
# 20     object
# 21     object
# 22     object
# 23     object
# 24     object
# 25     object
# 26     object
# 27     object
# 28     object
# 29     object
#         ...
# 211    object
# 212    object
# 213    object
# 214    object
# 215    object
# 216    object
# 217    object
# 218    object
# 219    object
# 220    object
# 221    object
# 222    object
# 223    object
# 224    object
# 225    object
# 226    object
# 227    object
# 228    object
# 229    object
# 230    object
# 231    object
# 232    object
# 233    object
# 234    object
# 235    object
# 236    object
# 237    object
# 238    object
# 239    object
# 240    object
# ...

# %%
df.shape
# Out:
# (1, 241)

# %% [markdown]
# **RESULTAT 1:** Im Lehrstellennachweis LENA gibt es **241** verschiedene Berufe.

# %%
df[value].count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f7defe9222bc> in <module>()
# ----> 1 df[value].count
#
# NameError: name 'value' is not defined
