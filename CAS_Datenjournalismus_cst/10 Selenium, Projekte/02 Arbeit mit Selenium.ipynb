# %% [markdown]
# # Arbeit mit Selenium

# %% [markdown]
# Die Arbeit mit Selenium erfordert etwas Übung. Aber der Zeitaufwand lohnt sich. Es gibt mit Selenium kaum ein Webdienst der nicht scrapbar wird. Beginnen wir aber wie üblich mit der Dokumentation. Sie ist im Falle von Selenium sehr hilfreich. Ihr findet [sie hier](http://selenium-python.readthedocs.io/). Und [hier](http://selenium-python.readthedocs.io/locating-elements.html).

# %% [markdown]
# Um Selenium kennenzulernen, gehen wir zurück zu unserem Beispiel der Lehren: https://www.berufsberatung.ch/dyn/show/2930. Nun wollen wir keine URLs generieren, um unsere Inhalte zu finden. Wir wollen stattdessen mit der Site interagieren. So sollten wir alle Einträge bekommen. BeautifulSoup werden wir trotzdem noch dazu nehmen. Denn Selenium liest keine Inhalte aus. Die Library lässt uns einfach mit dem Webdienst interagieren.

# %% [markdown]
# Beginnen wir mit den Imports

# %%
from bs4 import BeautifulSoup
import requests
import time  #bremst die Suchabfrage
import datetime #gibt die Möglichkeit Daten effizienter zu manipulieren
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# Und dann schicken wir Selenium auf die Seite.

# %%
#Wir starten den Browser:
driver = webdriver.Chrome('/usr/local/bin/chromedriver')
#Wir besuchen die Site
driver.get("https://www.berufsberatung.ch/dyn/show/2930")

# %% [markdown]
# ## Elemente ansteuern
# Nun suchen wir mit dem Inspector die Elemente, die wir ansteuern wollen.

# %%
# HTML-Code der Webseite untersuchen. Was löst das Dropdown-Menu aus?
# Aantwort: class = "fs-autocomplete-trigger".....

# %%
driver.find_element_by_class_name("fs-autocomplete-trigger").click()

# %%
# Test mit einer Berufs-ID
# HTML-Code checken für Abdecker > sw_453
driver.find_element_by_id("sw_453").click()

# %%
# Auf den Butten "TREFFER ANZEIGEN" klicken
driver.find_element_by_id("uxfs-action").click()

# %%
test = driver.page_source
# test       # Zeigt den HTML Code an
type(test) # Es handelt sich um einen String.
# Out:
# str

# %%
# Wie kann der HTML-Code, respektive String, abgespeichert werden?
file = open("berufsberatung_abdichter.html", "w") # leeres file öffnen und benennen, als txt oder html
file.write(test)                                   # leeres File füllen mit dem Strin "test"
file.close()

# %% [markdown]
# ## Liste mit den ID-Nummern generieren
# Aber wir wollen alle Ergänzen. Holen wir deshalb die Nummern nochmals mit BeautifulSoup und kreieren die Liste ids = [....]

# %%
r = requests.get('https://www.berufsberatung.ch/dyn/show/2930')
soup = BeautifulSoup(r.text, 'html.parser')

# %%
# Test
# soup.find('ul',{'class':'ui-autocomplete full-list '})

# %%
meine_id_list = soup.find('ul',{'class':'ui-autocomplete full-list '}).find_all('a')

# %%
meine_id_list[0]['data-id']
# Out:
# '453'

# %%
ids=[]
for tag in meine_id_list:
    tag = "sw_" + tag['data-id']
    ids.append(tag)

# %%
# Test. Die ersten fünf Elemente anzeigen
ids[:5]
# Out:
# ['sw_453', 'sw_452', 'sw_55', 'sw_7617', 'sw_7618']

# %% [markdown]
# Testen wir es mit den ersten fünf Einträgen

# %%
for elem in ids[:5]:
    print(elem)
    time.sleep(.5) #damit es nicht zu schnell geht
    driver.find_element_by_class_name("fs-autocomplete-trigger").click()
    time.sleep(.5)
    driver.find_element_by_id(elem).click()
# Out:
# sw_453
# sw_452
# sw_55
# sw_7617
# sw_7618

# %%
# vorher haben wir nur die Lehrstellen geadded, jetzt lösen wir die Suche aus
driver.find_element_by_id("uxfs-action").click()

# %% [markdown]
# Zeigen wird alle Ergebnisse an

# %%
# es werden nicht alle Suchresultate angezeigt. Man muss noch auf "Weitere anzeigen" klicken
driver.find_element_by_id("aSearchPaging").click()

# %% [markdown]
# Speichern wir die Ergebnisse ab

# %%
text = driver.page_source

# %%
def lehrstellen(html):
    
    soup = BeautifulSoup(html, 'html.parser')
    
    ortsliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell table-col-3'})
    
    firmenliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell bold company data-id table-col-1'})
    
    jahresliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell float-left-for-sd table-col-4'})
        
    anzahlliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell text-align-center float-left-for-sd table-col-5'})
    
    lst = []
    
    for ort, firma, jahr, anzahl in zip(ortsliste,firmenliste,jahresliste, anzahlliste):
        
        mini_dict = {'Ort':ort.text,
                     'Firma':firma.text,
                     'Jahr':jahr.text,
                     'Anzahl':int(anzahl.text.replace(' Lehrstelle(n)\n','').replace('\n',''))}
        lst.append(mini_dict)
    
    return lst

# %%
# !!! Backslash \ ermöglicht einen Zeilenumbruch

# %%
lehrstellen(text)
# Out:
# [{'Ort': 'Aadorf (TG)',
#   'Firma': 'Jakob Tanner AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Aesch BL (BL)',
#   'Firma': 'peressini roofing AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Alpnach Dorf (OW)',
#   'Firma': 'Abdichtungsbau Durrer AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Altendorf (SZ)',
#   'Firma': 'Marty Stefan AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Altstätten SG (SG)',
#   'Firma': 'Arthur Müggler & Co. AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Altstätten SG (SG)',
#   'Firma': 'Räss AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Amriswil (TG)',
#   'Firma': 'Vogel Dach- und Fassadenbau AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Amriswil (TG)',
#   'Firma': 'Weber Bedachungen',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bad Ragaz (SG)',
#   'Firma': 'Bürer Flachdach AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bassersdorf (ZH)',
#   'Firma': 'Carl Meier Sohn AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bätterkinden (BE)',
#   'Firma': 'E. Jörg AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Berg TG (TG)',
#   'Firma': 'Dörig Bedachungen Fassadenbau AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Biel/Bienne (BE)',
#   'Firma': 'De Luca Isolationen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bilten (GL)', 'Firma': 'Riget AG', 'Jahr': '2019', 'Anzahl': 2},
#  {'Ort': 'Cham (ZG)',
#   'Firma': 'schuler + helfenstein ag',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Chur (GR)', 'Firma': 'Meli AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Chur (GR)',
#   'Firma': "Meyer's Söhne AG",
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Crissier (VD)',
#   'Firma': 'Colas Suisse SA - succursale de Crissier',
#   'Jahr': '2018',
#   'Anzahl': 1},
#  {'Ort': 'Dallenwil (NW)',
#   'Firma': 'Odermatt Bedachungen und Spenglerei AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Dättwil AG (AG)',
#   'Firma': 'Schoop + Co. AG',
#   'Jahr': '2019',
#   'Anzahl': 3},
#  {'Ort': 'Degersheim (SG)',
#   'Firma': 'Giger GmbH Degersheim',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Dietikon (ZH)',
#   'Firma': 'W. Bosshard AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Dietikon (ZH)',
#   'Firma': 'Walo Bertschinger AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Domat/Ems (GR)',
#   'Firma': 'Dachbau Frei AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Düdingen (FR)',
#   'Firma': 'Ackermann AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Dürnten (ZH)', 'Firma': 'Blemo AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Ebikon (LU)', 'Firma': 'Banz AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Ebnat-Kappel (SG)',
#   'Firma': 'Roth Bedachungen Fassaden AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Echandens (VD)',
#   'Firma': 'Geneux-Dancet SA - Echandens',
#   'Jahr': '2018',
#   'Anzahl': 4},
#  {'Ort': 'Emmen (LU)', 'Firma': 'Bohl AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Emmenmatt (BE)',
#   'Firma': 'GLB Emmental',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Engelberg (OW)',
#   'Firma': 'BEPA Heinz Imboden AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Erlen (TG)', 'Firma': 'Boretti AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Erlenbach ZH (ZH)',
#   'Firma': 'Hans Hehlen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Evionnaz (VS (fr))',
#   'Firma': 'Sutech - Etanchéité SA',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Fällanden (ZH)', 'Firma': 'Burlet AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Fischingen (TG)',
#   'Firma': 'Schwager Bedachungen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Flühli LU (LU)',
#   'Firma': 'Wicki Dach- und Fassadenbau AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Flums (SG)',
#   'Firma': 'U. + H. Nadig Fassaden-Technik AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Frauenfeld (TG)',
#   'Firma': 'Beerli und Erné AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Frauenfeld (TG)',
#   'Firma': 'SC Haller AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Freiburg (FR)',
#   'Firma': 'Geneux Dancet SA',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Gampel (VS (de))',
#   'Firma': 'A. Kalbermatter AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Gerlafingen (SO)',
#   'Firma': 'Bernhard Dach & Fassaden AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Gossau SG (SG)', 'Firma': 'Schwizer', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Grüningen (ZH)',
#   'Firma': 'WB Bürgin AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Gunzgen (SO)',
#   'Firma': 'Roth Dach GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hägendorf (SO)',
#   'Firma': 'Eurodach AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hausen am Albis (ZH)',
#   'Firma': 'Fontana Dach & Fassaden AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Heimberg (BE)',
#   'Firma': 'Bauimpuls AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Heimberg (BE)',
#   'Firma': 'Gyger Flachdachbau AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Herzogenbuchsee (BE)',
#   'Firma': 'Kämpfer + Co. AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hinwil (ZH)',
#   'Firma': 'Gebrüder Looser AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hochdorf (LU)',
#   'Firma': 'von Büren Dach GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Horgen (ZH)', 'Firma': 'Jak. Mehr AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Ibach (SZ)',
#   'Firma': 'Kündig Josef AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Jona (SG)',
#   'Firma': 'Frei Bedachungen GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Kägiswil (OW)', 'Firma': 'Werth AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Kirchberg SG (SG)',
#   'Firma': 'Remo Schönenberger AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Knutwil (LU)',
#   'Firma': 'Bucher Bauspenglerei AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Langendorf (SO)',
#   'Firma': 'Schneitter AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Langenthal (BE)',
#   'Firma': 'Bernhard Polybau AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Le Lignon (GE)',
#   'Firma': 'G. Dentan Genève S.A.',
#   'Jahr': '2018',
#   'Anzahl': 1},
#  {'Ort': 'Les Acacias (GE)',
#   'Firma': 'Borga Toitures SA',
#   'Jahr': '2018',
#   'Anzahl': 1},
#  {'Ort': 'Liestal (BL)',
#   'Firma': 'Böhi + Wirz AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Luzern (LU)',
#   'Firma': 'Hans Racine AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Luzern (LU)',
#   'Firma': 'Schäfer Stammbach Partner AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Menznau (LU)',
#   'Firma': 'M. Kneubühler AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Mettlen (TG)',
#   'Firma': 'Mazzeo Bedachungen und Spenglerei AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Mollis (GL)',
#   'Firma': 'Elmer + Blumer Bedachungen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Näfels (GL)',
#   'Firma': 'casa-technica.ch',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Nänikon (ZH)',
#   'Firma': 'Aschwanden AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Niederglatt ZH (ZH)',
#   'Firma': 'Mohn + Partner AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Niederurnen (GL)',
#   'Firma': 'Ackermann Gebäudehüllen GmbH',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Oberengstringen (ZH)',
#   'Firma': 'Rolf Weidmann AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Oberriet SG (SG)',
#   'Firma': 'Hutter Bedachungen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Reinach BL (BL)',
#   'Firma': 'A+B Flachdach AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Rhäzüns (GR)',
#   'Firma': 'Burkhardt Gebäudehülle AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Romanshorn (TG)', 'Firma': 'Bühler', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Rorschach (SG)',
#   'Firma': 'Streule & Alder AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sargans (SG)',
#   'Firma': 'greencover ag',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schaan (FL)',
#   'Firma': 'Eberle Gebäudehülle AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schleitheim (SH)',
#   'Firma': 'Thomas Bollinger',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schlieren (ZH)',
#   'Firma': 'TECTON AG Zürich',
#   'Jahr': '2019',
#   'Anzahl': 3},
#  {'Ort': 'Schüpfheim (LU)',
#   'Firma': 'Markus Zemp',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schwarzenbach SG (SG)',
#   'Firma': 'Martin Schönenberger AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sirnach (TG)',
#   'Firma': 'Brändle Gebäudehüllen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sitten (VS (fr))',
#   'Firma': 'Geneux-Dancet SA',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'St. Gallen (SG)',
#   'Firma': 'Grob AG Gebäudehüllen',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'St. Gallen (SG)',
#   'Firma': 'Merz + Egger AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'St. Gallen (SG)',
#   'Firma': 'TECTON AG St. Gallen',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'St. Gallen (SG)', 'Firma': 'Weibel AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Sulgen (TG)',
#   'Firma': 'Schönenberger + Rieser AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sursee (LU)',
#   'Firma': 'Bedafa-Tech AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Tägerwilen (TG)',
#   'Firma': 'Brenner AG, Tägerwilen',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Thayngen (SH)', 'Firma': 'Scherrer', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Unterägeri (ZG)',
#   'Firma': 'Hansjörg Hug AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Unterägeri (ZG)',
#   'Firma': 'Schmidlin Spenglerei & Bedachungen',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Untervaz (GR)',
#   'Firma': "Hans Studach's Erben AG",
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Utzenstorf (BE)',
#   'Firma': 'Bernhard AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wabern (BE)',
#   'Firma': 'Guggisberg Dachtechnik AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Wädenswil (ZH)', 'Firma': 'Fischer AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Waldkirch (SG)',
#   'Firma': 'dach müggler ag',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wetzikon ZH (ZH)',
#   'Firma': 'BS Strohmeier AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wichtrach (BE)', 'Firma': 'Growe AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Widnau (SG)',
#   'Firma': 'Fritz Gresser AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Widnau (SG)',
#   'Firma': 'Spirig Vogel Haustech GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wil SG (SG)', 'Firma': 'B. Stillhart', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Wittenbach (SG)',
#   'Firma': 'Eigenmann AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wolhusen (LU)', 'Firma': 'Zihlmann AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Yverdon-les-Bains (VD)',
#   'Firma': 'Geneux-Dancet SA',
#   'Jahr': '2018',
#   'Anzahl': 1},
#  {'Ort': 'Zürich (ZH)', 'Firma': 'Preisig AG', 'Jahr': '2019', 'Anzahl': 2},
#  {'Ort': 'Zürich (ZH)',
#   'Firma': 'Scherrer Metec AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Aadorf (TG)',
#   'Firma': 'Jakob Tanner AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Altendorf (SZ)',
#   'Firma': 'Marty Stefan AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bad Ragaz (SG)',
#   'Firma': 'Bürer Flachdach AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bassersdorf (ZH)',
#   'Firma': 'Carl Meier Sohn AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Chur (GR)',
#   'Firma': "Meyer's Söhne AG",
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Dättwil AG (AG)',
#   'Firma': 'Schoop + Co. AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Degersheim (SG)',
#   'Firma': 'Giger GmbH Degersheim',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Dietikon (ZH)',
#   'Firma': 'W. Bosshard AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Domat/Ems (GR)',
#   'Firma': 'Dachbau Frei AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Emmen (LU)', 'Firma': 'Bohl AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Engelberg (OW)',
#   'Firma': 'BEPA Heinz Imboden AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Erlen (TG)', 'Firma': 'Boretti AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Fällanden (ZH)', 'Firma': 'Burlet AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Fischingen (TG)',
#   'Firma': 'Schwager Bedachungen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Flums (SG)',
#   'Firma': 'U. + H. Nadig Fassaden-Technik AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Frauenfeld (TG)',
#   'Firma': 'SC Haller AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Gunzgen (SO)',
#   'Firma': 'Roth Dach GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hochdorf (LU)',
#   'Firma': 'von Büren Dach GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Ibach (SZ)',
#   'Firma': 'Kündig Josef AG',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Kägiswil (OW)', 'Firma': 'Werth AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Kirchberg SG (SG)',
#   'Firma': 'Remo Schönenberger AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Luzern (LU)',
#   'Firma': 'Schäfer Stammbach Partner AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Menznau (LU)',
#   'Firma': 'M. Kneubühler AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Mettlen (TG)',
#   'Firma': 'Mazzeo Bedachungen und Spenglerei AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Mollis (GL)',
#   'Firma': 'Elmer + Blumer Bedachungen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Niederglatt ZH (ZH)',
#   'Firma': 'Mohn + Partner AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Niederurnen (GL)',
#   'Firma': 'Ackermann Gebäudehüllen GmbH',
#   'Jahr': '2019',
#   'Anzahl': 2},
#  {'Ort': 'Oberriet SG (SG)',
#   'Firma': 'Hutter Bedachungen AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Romanshorn (TG)', 'Firma': 'Bühler', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Rorschach (SG)',
#   'Firma': 'Streule & Alder AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sargans (SG)',
#   'Firma': 'greencover ag',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schwarzenbach SG (SG)',
#   'Firma': 'Martin Schönenberger AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sulgen (TG)',
#   'Firma': 'Schönenberger + Rieser AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Tägerwilen (TG)',
#   'Firma': 'Brenner AG, Tägerwilen',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wabern (BE)',
#   'Firma': 'Guggisberg Dachtechnik AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wädenswil (ZH)', 'Firma': 'Fischer AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Wetzikon ZH (ZH)',
#   'Firma': 'BS Strohmeier AG',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wichtrach (BE)', 'Firma': 'Growe AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Wittenbach (SG)', 'Firma': 'Dawag AG', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Attinghausen (UR)',
#   'Firma': 'Pferdestall Islern GmbH',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Bischofszell (TG)',
#   'Firma': 'Christian Hinder',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Braunau (TG)',
#   'Firma': 'Thomas Lehner',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Brülisau (AI)',
#   'Firma': 'Emil Manser-Brülisauer',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Brunnen (SZ)',
#   'Firma': 'Bucheli Bruno u. Cornelia',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Buochs (NW)',
#   'Firma': 'Betriebsgemeinschaft Odermatt/Wyrsch',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Diemtigen (BE)',
#   'Firma': 'Weibel Lucia',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Dörflingen (SH)',
#   'Firma': 'Aaron Ulrich',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Emmenmatt (BE)',
#   'Firma': 'Zürcher Daniel',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Frauenfeld (TG)',
#   'Firma': 'Fritz Stettler',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Grüningen (ZH)',
#   'Firma': 'Kündig Erwin',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Gundetswil (ZH)',
#   'Firma': 'Herzog Simon',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Heiden (AR)',
#   'Firma': 'Solenthaler-Oertle Johannes',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hölstein (BL)',
#   'Firma': 'Berger Heinz',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Hörhausen (TG)',
#   'Firma': 'Thomas Meier',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Kreuzlingen (TG)',
#   'Firma': 'Albert Neuweiler',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Kümmertshausen (TG)',
#   'Firma': 'Heinz Oswald',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Landquart (GR)',
#   'Firma': 'Landwirtschaftlicher Lehrbetriebsverbund',
#   'Jahr': '2019',
#   'Anzahl': 9},
#  {'Ort': 'Lindau (ZH)', 'Firma': 'Strickhof', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Lohn SH (SH)', 'Firma': 'Hannes Ehrat', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Märstetten (TG)',
#   'Firma': 'Franz Meier',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Mönchaltorf (ZH)',
#   'Firma': 'Kunz Heinz',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Oberburg (BE)',
#   'Firma': 'Kobel Werner',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Oberstammheim (ZH)',
#   'Firma': 'Farner Hanspeter',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Oetwil am See (ZH)',
#   'Firma': 'Gisler Josef',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Opfershofen TG (TG)',
#   'Firma': 'Christian Feller',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Ottoberg (TG)',
#   'Firma': 'Werner Beerli',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Rheinklingen (TG)',
#   'Firma': 'Philemon Stauffer',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Rothenthurm (SZ)',
#   'Firma': 'Abegg Anton',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schlattingen (TG)',
#   'Firma': 'Grob Gemüse- und Landbau',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Schönholzerswilen (TG)',
#   'Firma': 'Simon Schönholzer',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Sirnach (TG)',
#   'Firma': 'Christof Stutz',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Tägerschen (TG)',
#   'Firma': 'Peter Lüthi',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Tann (ZH)',
#   'Firma': 'Frischknecht Andreas',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Triesen (FL)',
#   'Firma': 'Schurti Leopold',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Truttikon (ZH)',
#   'Firma': 'Denzler Urs',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Wädenswil (ZH)',
#   'Firma': 'Kronauer Michael',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Walkringen (BE)',
#   'Firma': 'Friederika Stiftung',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Winden (TG)', 'Firma': 'Luzi Tanner', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Wollerau (SZ)',
#   'Firma': 'Sigrist-Keller Franz',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Fehraltorf (ZH)', 'Firma': 'Portulac', 'Jahr': '2019', 'Anzahl': 1},
#  {'Ort': 'Schlattingen (TG)',
#   'Firma': 'Grob Gemüse- und Landbau',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'St. Margrethen SG (SG)',
#   'Firma': 'Risch-Gemüse',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Therwil (BL)',
#   'Firma': 'Agrico-Genossenschaft',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'La Chaux-de-Fonds (NE)',
#   'Firma': 'Santschi Patric',
#   'Jahr': '2019',
#   'Anzahl': 1},
#  {'Ort': 'Les Breuleux (JU)',
#   'Firma': 'Surdez Romain',
#   'Jahr': '2018',
#   'Anzahl': 1},
#  {'Ort': 'Lignières (NE)',
#   'Firma': 'Exploitation du Receveur - Alain Schleppi',
#   'Jahr': '2019',
#   'Anzahl': 1}]

# %%
pd.DataFrame(lehrstellen(text))
# Out:
#      Anzahl                                      Firma  Jahr  \
# 0         1                            Jakob Tanner AG  2019
# 1         1                       peressini roofing AG  2019
# 2         1                   Abdichtungsbau Durrer AG  2019
# 3         1                            Marty Stefan AG  2019
# 4         1                    Arthur Müggler & Co. AG  2019
# 5         1                                    Räss AG  2019
# 6         1             Vogel Dach- und Fassadenbau AG  2019
# 7         1                          Weber Bedachungen  2019
# 8         1                         Bürer Flachdach AG  2019
# 9         1                         Carl Meier Sohn AG  2019
# 10        1                                 E. Jörg AG  2019
# 11        1           Dörig Bedachungen Fassadenbau AG  2019
# 12        1                     De Luca Isolationen AG  2019
# 13        2                                   Riget AG  2019
# 14        1                   schuler + helfenstein ag  2019
# 15        1                                    Meli AG  2019
# 16        2                           Meyer's Söhne AG  2019
# 17        1   Colas Suisse SA - succursale de Crissier  2018
# 18        1     Odermatt Bedachungen und Spenglerei AG  2019
# 19        3                            Schoop + Co. AG  2019
# 20        1                      Giger GmbH Degersheim  2019
# 21        1                             W. Bosshard AG  2019
# 22        2                       Walo Bertschinger AG  2019
# 23        1                            Dachbau Frei AG  2019
# 24        1                               Ackermann AG  2019
# 25        1                                   Blemo AG  2019
# 26        1                                    Banz AG  2019
# 27        2               Roth Bedachungen Fassaden AG  2019
# 28        4               Geneux-Dancet SA - Echandens  2018
# 29        1                                    Bohl AG  2019
# ..      ...                                        ...   ...
# 169       9   Landwirtschaftlicher Lehrbetriebsverbund  2019
# 170       1                                  Strickhof  2019
# 171       1                               Hannes Ehrat  2019
# 172       1                                Franz Meier  2019
# 173       1                                 Kunz Heinz  2019
# 174       1                               Kobel Werner  2019
# 175       1                           Farner Hanspeter  2019
# 176       1                               Gisler Josef  2019
# 177       1                           Christian Feller  2019
# 178       1                              Werner Beerli  2019
# 179       1                          Philemon Stauffer  2019
# 180       1                                Abegg Anton  2019
# 181       1                   Grob Gemüse- und Landbau  2019
# 182       1                          Simon Schönholzer  2019
# 183       1                             Christof Stutz  2019
# 184       1                                Peter Lüthi  2019
# 185       1                       Frischknecht Andreas  2019
# 186       1                            Schurti Leopold  2019
# 187       1                                Denzler Urs  2019
# 188       1                           Kronauer Michael  2019
# 189       1                        Friederika Stiftung  2019
# 190       1                                Luzi Tanner  2019
# 191       1                       Sigrist-Keller Franz  2019
# 192       1                                   Portulac  2019
# 193       1                   Grob Gemüse- und Landbau  2019
# 194       1                               Risch-Gemüse  2019
# 195       1                      Agrico-Genossenschaft  2019
# 196       1                            Santschi Patric  2019
# 197       1                              Surdez Romain  2018
# 198       1  Exploitation du Receveur - Alain Schleppi  2019
#
#                         Ort
# 0               Aadorf (TG)
# 1             Aesch BL (BL)
# 2         Alpnach Dorf (OW)
# 3            Altendorf (SZ)
# 4        Altstätten SG (SG)
# 5        Altstätten SG (SG)
# 6             Amriswil (TG)
# 7             Amriswil (TG)
# 8            Bad Ragaz (SG)
# 9          Bassersdorf (ZH)
# 10        Bätterkinden (BE)
# 11             Berg TG (TG)
# 12         Biel/Bienne (BE)
# 13              Bilten (GL)
# 14                Cham (ZG)
# 15                Chur (GR)
# 16                Chur (GR)
# 17            Crissier (VD)
# 18           Dallenwil (NW)
# 19          Dättwil AG (AG)
# 20          Degersheim (SG)
# 21            Dietikon (ZH)
# 22            Dietikon (ZH)
# 23           Domat/Ems (GR)
# 24            Düdingen (FR)
# 25             Dürnten (ZH)
# 26              Ebikon (LU)
# 27        Ebnat-Kappel (SG)
# 28           Echandens (VD)
# 29               Emmen (LU)
# ..                      ...
# 169          Landquart (GR)
# 170             Lindau (ZH)
# 171            Lohn SH (SH)
# 172         Märstetten (TG)
# 173        Mönchaltorf (ZH)
# 174           Oberburg (BE)
# 175      Oberstammheim (ZH)
# 176      Oetwil am See (ZH)
# 177     Opfershofen TG (TG)
# 178           Ottoberg (TG)
# 179       Rheinklingen (TG)
# 180        Rothenthurm (SZ)
# 181       Schlattingen (TG)
# 182  Schönholzerswilen (TG)
# 183            Sirnach (TG)
# 184         Tägerschen (TG)
# 185               Tann (ZH)
# 186            Triesen (FL)
# 187          Truttikon (ZH)
# 188          Wädenswil (ZH)
# 189         Walkringen (BE)
# 190             Winden (TG)
# 191           Wollerau (SZ)
# 192         Fehraltorf (ZH)
# 193       Schlattingen (TG)
# 194  St. Margrethen SG (SG)
# 195            Therwil (BL)
# 196  La Chaux-de-Fonds (NE)
# 197       Les Breuleux (JU)
# 198          Lignières (NE)
#
# [199 rows x 4 columns]

# %% [markdown]
# ## Bringen wir alles zusammen

# %% [markdown]
# ACHTUNG nicht zu schnell weiterklicken: (*) muss verschwinden.
# statt lxml muss html.parser stehen

# %%
#Funktion, um nur die Informationen herauszuziehen, die uns interessieren
def lehrstellen(html):
    
    soup = BeautifulSoup(html, 'html.parser')
    try:
        ortsliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell table-col-3'})
    
        firmenliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell bold company data-id table-col-1'})
    
        jahresliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell float-left-for-sd table-col-4'})
        
        anzahlliste = soup.find('div', {'class':'resultpart result-body'})\
                    .find_all('div', {'class':'display-table-cell text-align-center float-left-for-sd table-col-5'})
    
        lehrstelle = soup.find('ul',{'class':'ui-autocomplete full-list '})\
                    .find_all('a')
        lst = []
    
        for ort, firma, jahr, anzahl,lehr in zip(ortsliste,firmenliste,jahresliste, anzahlliste,lehrstelle):
        
            mini_dict = {'Ort':ort.text,
                     'Firma':firma.text,
                     'Jahr':jahr.text,
                     'Anzahl':int(anzahl.text.replace(' Lehrstelle(n)\n','').replace('\n','')),
                     'Lehrstelle':lehr['data-value']}
            lst.append(mini_dict)
    
        return pd.DataFrame(lst).to_csv("d/"+str(datetime.datetime.now())+".csv")
    
    except:
        return pd.DataFrame([{'Ort':'Keine Treffer',
                'Firma':'Keine Treffer',
                'Jahr':'Keine Treffer',
                'Anzahl':'Keine Treffer'}])
    
#Bauen wir Listen aller Job-IDs
r = requests.get('https://www.berufsberatung.ch/dyn/show/2930')
soup = BeautifulSoup(r.text, 'html.parser')
ids = []
for elem in soup.find('ul',{'class':'ui-autocomplete full-list '}).find_all('a'):
    elem = "sw_" + elem['data-id']
    ids.append(elem)
    
#Teilen wir diese Listen mit Länge von je 5 Teilen. 
#Das habe ich nicht selber geschrieben, sondern hier geholt:
#https://stackoverflow.com/questions/312443/how-do-you-split-a-list-into-evenly-sized-chunks
idslst = [ids[i:i + 5] for i in range(0, len(ids), 5)]

count = 0
for ids in idslst:

    #Starten wir den Chrome-Browser und besuchen die Site
    driver = webdriver.Chrome('/usr/local/bin/chromedriver')
    driver.get("https://www.berufsberatung.ch/dyn/show/2930")

    #Bereiten wir die Suche vor    
    for elem in ids:
        time.sleep(1) #damit es nicht zu schnell geht
        driver.find_element_by_class_name("fs-autocomplete-trigger").click()
        time.sleep(1)
        driver.find_element_by_id(elem).click()
    
    #Suchen wir
    time.sleep(1)
    driver.find_element_by_id("uxfs-action").click()

    #Nun nun sorgen wir dafür, dass alle Ergebnisse anzeigt werden.
    exists = 1
    while(exists==1):
        loadmore = driver.find_element_by_id("aSearchPaging")
        if loadmore.text == "MEHR ERGEBNISSE ANZEIGEN":
            driver.find_element_by_id("aSearchPaging").click()
            time.sleep(1)
        else:
            exists = 0
            
    print(count)
    count += 1
    
    lehrstellen(driver.page_source)
    driver.close()
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# Kreieren wir ein kleine .py File und lösen es von der Commandline aus.
