# %% [markdown]
# # 1.1 Entwicklung Request.post()-Methode

# %% [markdown]
# Heute sind viele spezialisierte Fachkräfte oft nur noch im Ausland zu finden. Mit den Abkommen zwischen der Schweiz und der EU ist jedoch der Zugang für Arbeitnehmer aus den EU-Staaten zum Schweizer wie auch Liechteinsteiner Arbeitsmarkt kein Problem mehr.
#
# Schweizer Firmen suchen Arbeitsdkräfte im Ausland via Rekrutierer, internationalen oder nationalen Jobplattformen. Eine solche Jobplattform ist EURES (https://ec.europa.eu/eures/public/de/ ) eine Jobplattform der EU.
#
# Ziel ist herauszufinden welche Skills die Schweizer Firmen im Ausland suchen.

# %% [markdown]
# ## Schritt 1: Import der Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Schritt 2: Erste Abfrage

# %% [markdown]
# Auf EURES sind aktuell 3'893'033 Stellen ausgeschrieben, davon 4'625 von Schweizer Firmen (Stand 8.2.2019).

# %% [markdown]
# ### Versuch 1 mit BeautifulSoup

# %%
url = 'https://ec.europa.eu/eures/eures-searchengine/page/main#/search'
content = requests.get(url).text 
soup = BeautifulSoup(content, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html><head>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="en" http-equiv="Content-Language"/>
# <link href="	/eures/eures-searchengine/assets/gfx/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="	/eures/eures-searchengine/assets/gfx/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="eures, directorate general of employment, employment, jobs, european jobs, living and working, living and working in europe, free movement, labour market information, european labour market information, european union, eu" name="keywords"/>
# <meta content="2.1.1p1-build-0" name="Release Build Version"/>
# ...

# %% [markdown]
# ### Versuch 2 mit Request.post()-Methode

# %% [markdown]
# Die Suppe gibt keinen Inhalt zurück. Kontrollieren auf der Webseite: https://ec.europa.eu/eures/eures-searchengine/page/main#/search öffnen. Im Browser-Fenster Develepoers Tool nutzen: Inspect Element öffnen > auf Network klicken > bisherige Anfragen löschen > Switzerland auswählen > auf POST klicken > mit ctrl+ anklicken und auf Copy/Copyascurl klicken

# %% [markdown]
# curl 'https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search?lang=en&app=2.1.1p1-build-0' -H 'User-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:65.0) Gecko/20100101 Firefox/65.0' -H 'Accept: application/json, text/plain, */*' -H 'Accept-Language: en-US,en;q=0.5' --compressed -H 'Referer: https://ec.europa.eu/eures/eures-searchengine/page/main?lang=en&app=3.1.1-build-1' -H 'ajax-call: true' -H 'Content-Type: application/json;charset=utf-8' -H 'Connection: keep-alive' -H 'Cookie: cck_read=%22en%22; _pk_id.81.1e93=8242111674440e7c.1549812996.2.1549818779.1549813593.; _pk_ref.81.1e93=%5B%22%22%2C%22%22%2C1549818312%2C%22https%3A%2F%2Fec.europa.eu%2Feures%2Feures-apps%2Fum%2Fpage%2Fpublic%3Flang%3Den%22%5D; EURES_JVSE_SESSIONID=7OLYXrTVF7b1PqZg5PGIpWIfVrYqP26q-pePlwY65R2wCkdXoPJB!-1540004032; EURES_CVO_SESSIONID=_fPYEHRqxUcDk1to8wSZjCkMekZZjEVuISYSEMUCbFRHa0Bcd8yF!-1456100611; EURES_CVSE_SESSIONID=78DYFWXh4Qk1gDmTdqXGzxsNB8-ISP2Js2NVT2MACTgiDCd785vm!-1456100611; EURES_PORTAL_SESSIONID=lwDYFh4RsE9N3awqwimhwRXl3pzCyexymHaw2n-ZW-aY99G4lDwj!-715995346; EURES_UM_SESSIONID=1YHYFlQUYLKjKCn_UFo_W5_UnHa6jtK6dllokblNKFYqoUvfgDi2!-1456100611; _pk_ses.81.1e93=*; LFR_SESSION_STATE_10159=1549813544383; eu_cookie_consent=%7B%22a%22%3A%7B%22document.domain%22%3A%5B%22_gat%22%2C%22_ga%22%2C%22jobVacancy%22%2C%22ISCOLang%22%5D%7D%2C%22r%22%3A%7B%7D%7D; _ga=GA1.2.1678820704.1549813001; _gid=GA1.2.780842180.1549813001; JSESSIONID=0SjYFe6jyLtOEF72JiO7d62Hiqy1iMZrjpTS0ENDxEzNdWP7u9Rt!-821628854' --data '{"keywords":[],"positionScheduleCodes":[],"positionOfferingCodes":[],"educationLevelCodes":[],"euresFlagCodes":[],"nutsCodes":["ch"],"notSpecifiedInNutsCodes":[],"requiredExperienceCodes":[],"solidarityContextCodes":[],"otherBenefitsCodes":[],"occupationUris":[],"includeJobsWithoutBenefits":false,"requiredLanguages":[],"includeJobsWithoutRequiredLanguages":false,"sortSearch":"BEST_MATCH","resultsPerPage":10,"page":1,"sessionId":"pm42rmjq6oszjee9672r5f"}'

# %%
# Unter "nutsCodes":["ch"] wird die Schweiz definiert
# Es wird die erste Seite mit 10 Resultaten angezeigt

# %%
url = 'https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search?lang=en&app=2.1.1p1-build-0'
data = '{"keywords":[],"positionScheduleCodes":[],"positionOfferingCodes":[],"educationLevelCodes":[],"euresFlagCodes":[],"nutsCodes":["ch"],"notSpecifiedInNutsCodes":[],"requiredExperienceCodes":[],"solidarityContextCodes":[],"otherBenefitsCodes":[],"occupationUris":[],"includeJobsWithoutBenefits":false,"requiredLanguages":[],"includeJobsWithoutRequiredLanguages":false,"sortSearch":"BESTMATCH","resultsPerPage":10,"page":1,"sessionId":"pm42rmjq6oszjee9672r5f"}'
r = requests.post(url, data = data)
print(r)
# Out:
# <Response [500]>

# %% [markdown]
# ### Debugging 1

# %% [markdown]
# Error-Meldung > Die Anfrage gibt keine Daten zurück
# Zuerst checken: bleibt die Session-ID die gleiche?
# mehr mitgeben wie zB Header und Cookies..

# %%
url = 'https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search?lang=en&app=2.1.1p1-build-0'

data = {
    "keywords":[],
    "positionScheduleCodes":[],
    "positionOfferingCodes":[],
    "educationLevelCodes":[],
    "euresFlagCodes":[],
    "nutsCodes":["ch"],
    "notSpecifiedInNutsCodes":[],
    "requiredExperienceCodes":[],
    "solidarityContextCodes":[],
    "otherBenefitsCodes":[],
    "occupationUris":[],
    "includeJobsWithoutBenefits":False, 
    "requiredLanguages":[],
    "includeJobsWithoutRequiredLanguages":False,
    "sortSearch":"BESTMATCH",
    "resultsPerPage":10,
    "page":1,
    "sessionId":"pm42rmjq6oszjee9672r5f"
        }
headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:65.0) Gecko/20100101 Firefox/65.0',
    'Accept': 'application/json, text/plain, /*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://ec.europa.eu/eures/eures-searchengine/page/main?lang=en&app=3.1.1-build-1',
    'ajax-call': 'true',
    'Content-Type': 'application/json;charset=utf-8',
    'Connection': 'keep-alive'
        }
cookies = {
   'Cookie': 'cck_read=%22en%22; pkid.81.1e93=8242111674440e7c.1549812996.2.1549818779.1549813593.; pkref.81.1e93=%5B%22%22%2C%22%22%2C1549818312%2C%22https%3A%2F%2Fec.europa.eu%2Feures%2Feures-apps%2Fum%2Fpage%2Fpublic%3Flang%3Den%22%5D; EURES_JVSE_SESSIONID=7OLYXrTVF7b1PqZg5PGIpWIfVrYqP26q-pePlwY65R2wCkdXoPJB!-1540004032; EURES_CVO_SESSIONID=fPYEHRqxUcDk1to8wSZjCkMekZZjEVuISYSEMUCbFRHa0Bcd8yF!-1456100611; EURESCVSE_SESSIONID=78DYFWXh4Qk1gDmTdqXGzxsNB8-ISP2Js2NVT2MACTgiDCd785vm!-1456100611; EURES_PORTAL_SESSIONID=lwDYFh4RsE9N3awqwimhwRXl3pzCyexymHaw2n-ZW-aY99G4lDwj!-715995346; EURES_UM_SESSIONID=1YHYFlQUYLKjKCn_UFo_W5_UnHa6jtK6dllokblNKFYqoUvfgDi2!-1456100611; pkses.81.1e93=; LFR_SESSION_STATE_10159=1549813544383; eu_cookie_consent=%7B%22a%22%3A%7B%22document.domain%22%3A%5B%22_gat%22%2C%22_ga%22%2C%22jobVacancy%22%2C%22ISCOLang%22%5D%7D%2C%22r%22%3A%7B%7D%7D; ga=GA1.2.1678820704.1549813001; _gid=GA1.2.780842180.1549813001; JSESSIONID=0SjYFe6jyLtOEF72JiO7d62Hiqy1iMZrjpTS0ENDxEzNdWP7u9Rt!-821628854'
}
        
r = requests.post(url, data = data, headers = headers, cookies = cookies)
print(r.text)

# false gross schreiben damit Python den Begriff als Bool erkennt
# Out:
# The HTTP header field "Accept" with value "application/json, text/plain, /*" could not be parsed.

# %% [markdown]
# ### Debugging 2

# %% [markdown]
# **Curl-Befehl** aus dem Browser unter https://curl.trillworks.com/ einfügen, ergibt eine Python-Request-Anfrage.

# %%
import requests

url = 'https://ec.europa.eu/eures/eures-searchengine/page/jv-search/search'

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:65.0) Gecko/20100101 Firefox/65.0',
    'Accept': 'application/json, text/plain, /*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://ec.europa.eu/eures/eures-searchengine/page/main?lang=en&app=3.1.1-build-1',
    'ajax-call': 'true',
    'Content-Type': 'application/json;charset=utf-8',
    'Connection': 'keep-alive'
}

params = (
    ('lang', 'en'),
    ('app', '2.1.1p1-build-0'),
)

cookies = {
    'cck_read': '%22en%22',
    'pkid.81.1e93': '8242111674440e7c.1549812996.2.1549818779.1549813593.',
    'pkref.81.1e93': '%5B%22%22%2C%22%22%2C1549818312%2C%22https%3A%2F%2Fec.europa.eu%2Feures%2Feures-apps%2Fum%2Fpage%2Fpublic%3Flang%3Den%22%5D',
    'EURES_JVSE_SESSIONID': '7OLYXrTVF7b1PqZg5PGIpWIfVrYqP26q-pePlwY65R2wCkdXoPJB!-1540004032',
    'EURES_CVO_SESSIONID': 'fPYEHRqxUcDk1to8wSZjCkMekZZjEVuISYSEMUCbFRHa0Bcd8yF!-1456100611',
    'EURESCVSE_SESSIONID': '78DYFWXh4Qk1gDmTdqXGzxsNB8-ISP2Js2NVT2MACTgiDCd785vm!-1456100611',
    'EURES_PORTAL_SESSIONID': 'lwDYFh4RsE9N3awqwimhwRXl3pzCyexymHaw2n-ZW-aY99G4lDwj!-715995346',
    'EURES_UM_SESSIONID': '1YHYFlQUYLKjKCn_UFo_W5_UnHa6jtK6dllokblNKFYqoUvfgDi2!-1456100611',
    'pkses.81.1e93': '',
    'LFR_SESSION_STATE_10159': '1549813544383',
    'eu_cookie_consent': '%7B%22a%22%3A%7B%22document.domain%22%3A%5B%22_gat%22%2C%22_ga%22%2C%22jobVacancy%22%2C%22ISCOLang%22%5D%7D%2C%22r%22%3A%7B%7D%7D',
    'ga': 'GA1.2.1678820704.1549813001',
    '_gid': 'GA1.2.780842180.1549813001',
    'JSESSIONID': '0SjYFe6jyLtOEF72JiO7d62Hiqy1iMZrjpTS0ENDxEzNdWP7u9Rt!-821628854',
}

data = '''{
    "keywords":[],
    "positionScheduleCodes":[],
    "positionOfferingCodes":[],
    "educationLevelCodes":[],
    "euresFlagCodes":[],
    "nutsCodes":["ch"],
    "notSpecifiedInNutsCodes":[],
    "requiredExperienceCodes":[],
    "solidarityContextCodes":[],
    "otherBenefitsCodes":[],
    "occupationUris":[],
    "includeJobsWithoutBenefits":false,
    "requiredLanguages":[],
    "includeJobsWithoutRequiredLanguages":false,
    "sortSearch":"BESTMATCH",
    "resultsPerPage":10,
    "page":1,
    "sessionId":"pm42rmjq6oszjee9672r5f"
}'''

r = requests.post(url, headers=headers, params=params, cookies=cookies, data=data)

print(r.text)
# Out:
# The HTTP header field "Accept" with value "application/json, text/plain, /*" could not be parsed.

# %%
# umformatieren und dann verstehen, wie das ganze strukturiert ist 
r.json()

# %% [markdown]
# #### <font color='red'>> Die grosse kombinierte Abfrage findet sich im nächsten Jupyter Notebook "2 Scraper"</font>
